# %%
from textblob import TextBlob
import pandas as pd
import re

# %%
def clean_text(text): 
        ''' 
        Utility function to clean text by removing links,
        special characters using simple regex statements. 
        '''
        return ' '.join(re.sub("(@[A-Za-z0-9]+)|([^0-9A-Za-z \t])|(\w+:\/\/\S+)", " ", text).split()) 

def get_text_sentiment(text):
    ''' 
    Utility function to classify sentiment of passed
    text using textblob's sentiment method 
    '''
    # create TextBlob object of passed text 
    analysis = TextBlob(clean_text(text)) 
    # set sentiment 
    if analysis.sentiment.polarity > 0: 
        return 'positive'
    elif analysis.sentiment.polarity == 0: 
        return 'neutral'
    else: 
        return 'negative'

# %%
def feature_extraction(text): 
        blob = TextBlob(text)
        return blob.noun_phrases

# %%
dataset = pd.read_csv("G:/PuthonRun/Amazon_Review/data/Amazon_Unlocked_Mobile.csv")
dataset.head()
# Out:
#                                         Product Name Brand Name   Price  \
# 0  "CLEAR CLEAN ESN" Sprint EPIC 4G Galaxy SPH-D7...    Samsung  199.99
# 1  "CLEAR CLEAN ESN" Sprint EPIC 4G Galaxy SPH-D7...    Samsung  199.99
# 2  "CLEAR CLEAN ESN" Sprint EPIC 4G Galaxy SPH-D7...    Samsung  199.99
# 3  "CLEAR CLEAN ESN" Sprint EPIC 4G Galaxy SPH-D7...    Samsung  199.99
# 4  "CLEAR CLEAN ESN" Sprint EPIC 4G Galaxy SPH-D7...    Samsung  199.99
#
#    Rating                                            Reviews  Review Votes
# 0       5  I feel so LUCKY to have found this used (phone...           1.0
# 1       4  nice phone, nice up grade from my pantach revu...           0.0
# 2       5                                       Very pleased           0.0
# 3       4  It works good but it goes slow sometimes but i...           0.0
# 4       4  Great phone to replace my lost phone. The only...           0.0

# %%
#Selecting a subset from dataset
subset_sample=dataset.loc[dataset['Product Name'] == "Samsung Convoy U640 Phone for Verizon Wireless Network with No Contract (Gray) Rugged"]
subset_sample.head()
# Out:
#                                              Product Name Brand Name  Price  \
# 413473  Samsung Convoy U640 Phone for Verizon Wireless...    Samsung  79.95
# 413474  Samsung Convoy U640 Phone for Verizon Wireless...    Samsung  79.95
# 413475  Samsung Convoy U640 Phone for Verizon Wireless...    Samsung  79.95
# 413476  Samsung Convoy U640 Phone for Verizon Wireless...    Samsung  79.95
# 413477  Samsung Convoy U640 Phone for Verizon Wireless...    Samsung  79.95
#
#         Rating                                            Reviews  \
# 413473       5  I loved it. It was in good shape. I wanted an ...
# 413474       5  Great phone to use with page plus cellular min...
# 413475       3  This is probably a phone that was used very ha...
# 413476       1  The Pnone was a piece of junkIt was all scratc...
# 413477       5  While it was listed as refurbished, it appears...
#
#         Review Votes
# 413473           0.0
# 413474           0.0
# 413475           0.0
# 413476           1.0
# 413477           0.0

# %%
#subset_sample['Reviews']
#Extracting Features from subset
features = []
for reviews in subset_sample['Reviews']:
    features.append(feature_extraction(reviews))
    
subset_sample["features"] = features
subset_sample.head()
# Out:
# C:\Users\OKOK D2\AppData\Local\Temp\ipykernel_13840\3488151437.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   subset_sample["features"] = features
#                                              Product Name Brand Name  Price  \
# 413473  Samsung Convoy U640 Phone for Verizon Wireless...    Samsung  79.95
# 413474  Samsung Convoy U640 Phone for Verizon Wireless...    Samsung  79.95
# 413475  Samsung Convoy U640 Phone for Verizon Wireless...    Samsung  79.95
# 413476  Samsung Convoy U640 Phone for Verizon Wireless...    Samsung  79.95
# 413477  Samsung Convoy U640 Phone for Verizon Wireless...    Samsung  79.95
#
#         Rating                                            Reviews  \
# 413473       5  I loved it. It was in good shape. I wanted an ...
# 413474       5  Great phone to use with page plus cellular min...
# 413475       3  This is probably a phone that was used very ha...
# 413476       1  The Pnone was a piece of junkIt was all scratc...
# 413477       5  While it was listed as refurbished, it appears...
#
#         Review Votes                                           features
# 413473           0.0                          [good shape, perfect fit]
# 413474           0.0  [great phone, cellular minutes, esn, long batt...
# 413475           0.0                                                 []
# 413476           1.0                             [pnone, ownernot hapy]
# 413477           0.0                              [excellent condition]

# %%
#subset_sample['Reviews']
sentiment = []
for reviews in subset_sample['Reviews']:
    sentiment.append(get_text_sentiment(reviews))
    
subset_sample["Sentiment"] = sentiment
subset_sample.head()
# Out:
# C:\Users\OKOK D2\AppData\Local\Temp\ipykernel_13840\3776669054.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   subset_sample["Sentiment"] = sentiment
#                                              Product Name Brand Name  Price  \
# 413473  Samsung Convoy U640 Phone for Verizon Wireless...    Samsung  79.95
# 413474  Samsung Convoy U640 Phone for Verizon Wireless...    Samsung  79.95
# 413475  Samsung Convoy U640 Phone for Verizon Wireless...    Samsung  79.95
# 413476  Samsung Convoy U640 Phone for Verizon Wireless...    Samsung  79.95
# 413477  Samsung Convoy U640 Phone for Verizon Wireless...    Samsung  79.95
#
#         Rating                                            Reviews  \
# 413473       5  I loved it. It was in good shape. I wanted an ...
# 413474       5  Great phone to use with page plus cellular min...
# 413475       3  This is probably a phone that was used very ha...
# 413476       1  The Pnone was a piece of junkIt was all scratc...
# 413477       5  While it was listed as refurbished, it appears...
#
#         Review Votes                                           features  \
# 413473           0.0                          [good shape, perfect fit]
# 413474           0.0  [great phone, cellular minutes, esn, long batt...
# 413475           0.0                                                 []
# 413476           1.0                             [pnone, ownernot hapy]
# 413477           0.0                              [excellent condition]
#
#        Sentiment
# 413473  positive
# 413474  positive
# 413475  negative
# 413476   neutral
# 413477  positive

# %%
#Features With their counts
counts = {}
def feature_count(feature):
        if  feature in counts:
            counts[feature] += 1
        else:
            counts[feature] = 1
for feature_list in subset_sample['features']:
    for feature in feature_list:
        feature_count(feature)

# %%
print(counts)
# Out:
# {'good shape': 4, 'perfect fit': 2, 'great phone': 18, 'cellular minutes': 2, 'esn': 2, 'long battery life': 4, 'pnone': 2, 'ownernot hapy': 2, 'excellent condition': 3, 'easy': 6, 'ordered': 2, 'according': 2, 'good condition': 12, 'u640': 3, 'lg': 3, 'battery life': 6, 'family plan': 2, 'verizon': 30, 'yes': 2, 'rugged': 3, 'great battery life': 3, 'car charger': 2, "car 's fault": 2, 'cosmetic dings': 2, 'cell phone': 10, 'upon': 6, 'flip phones': 9, 'power mechanism': 2, 'battery power.bottom line': 2, 'true statement': 2, 'use phone': 2, 'electrical contractor': 2, 'rough work': 2, 'one.the sellar': 2, 'samsung convoy': 5, 'w/o problems': 2, 'extra charges': 2, 'future i': 2, "n't need alot": 2, 'experience problems': 2, 'phone i': 2, 'battery pack': 2, "n't making": 2, 'correct connection': 2, 'small piece': 2, 'august': 2, 'year i': 2, 'junk phone': 2, 'sense thrown': 2, 'cell phone provider': 2, 'chargers didnt work': 2, 'withthe buyer': 2, 'perfect': 5, 'work phone': 3, 'love it': 2, 'item': 2, 'previous owner': 2, 'just need': 2, 'battery lasts': 3, 'days': 2, 'great price': 9, 'ok': 6, 'passes': 2, 'drop test': 2, 'porcelain tile': 2, 'good selection': 2, 'v-cast': 2, 'rhapsody': 2, "n't lnow": 2, 'bad resolution': 2, 'good camera': 2, 'overall': 3, 'good audio': 